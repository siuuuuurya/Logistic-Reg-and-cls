# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression 
from sklearn.metrics import accuracy_score, classification_report

# %%
df = pd.read_csv("/Users/siuuuuurya/Desktop/excelfiles/admission_data.csv")

# %%
df_x =  df.drop(['Admitted'], axis = 1)

# %%
df_y = df.Admitted

# %%
x_train , x_test ,y_train ,y_test = train_test_split(df_x , df_y, test_size=0.1 ,random_state= 42)

# %%
Model = LogisticRegression()
Model.fit(x_train, y_train)
predicted = Model.predict(x_test)

# %%
predicted
# Out:
# array([1, 1, 1])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   GRE       25 non-null     int64
#  1   TOEFL     25 non-null     int64
#  2   SOP       25 non-null     float64
#  3   CGPA      25 non-null     float64
#  4   Research  25 non-null     int64
#  5   Admitted  25 non-null     int64
# dtypes: float64(2), int64(4)
# memory usage: 1.3 KB

# %%
Model.score(x_test,y_test)
# Out:
# 1.0

# %%
print("Accuracy Score : ", accuracy_score(y_test,predicted))
# Out:
# Accuracy Score :  1.0

# %%
print("Classification Report : ", classification_report(y_test,predicted))
# Out:
# Classification Report :                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00         3
#
#     accuracy                           1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3

# %% [markdown]
# ## --------- Prediction for a new Student --------------

# %%
df
# Out:
#     GRE  TOEFL  SOP  CGPA  Research  Admitted
# 0   320    110  4.5   9.0         1         1
# 1   300    100  3.0   8.0         0         0
# 2   310    105  3.5   8.5         1         1
# 3   290     95  2.5   7.0         0         0
# 4   340    115  5.0   9.8         1         1
# 5   280     90  2.0   6.8         0         0
# 6   330    112  4.8   9.6         1         1
# 7   305    102  3.2   8.1         0         0
# 8   315    108  4.0   8.9         1         1
# 9   295     97  2.8   7.2         0         0
# 10  325    111  4.2   9.3         1         1
# 11  310    103  3.5   8.4         1         1
# 12  300     99  3.0   7.8         0         0
# 13  290     93  2.4   6.9         0         0
# 14  335    114  4.9   9.7         1         1
# 15  275     88  2.0   6.5         0         0
# 16  312    106  3.8   8.6         1         1
# 17  298    101  3.1   7.9         0         0
# 18  322    109  4.6   9.2         1         1
# ...

# %%
gre = int(input("Enter GRE") ) 
toefl =int(input("Enter TOEFL")) 
sop = float(input("Enter SOP")) 
cgpa =float(input("Enter CGPA")) 
reasearch = bool(int(input("0 is NO , 1 is YES")))
# Out:
# Enter GRE 335
# Enter TOEFL 114
# Enter SOP 4.9
# Enter CGPA 9.7
# 0 is NO , 1 is YES 1

# %%
prediction = Model.predict([[gre, toefl, sop, cgpa, reasearch]])
print(prediction)
# Out:
# [1]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
